# %% [markdown]
# <a href="https://colab.research.google.com/github/Oscaritd/Simulacion-/blob/main/Unidad%203/Practica_4_Distribucion_LogNormal_Tiempos_de_inactividad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #SIMULACION
# ##Practica 4

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# Parámetro de la distribución Poisson (media de la demanda diaria)
lambda_poisson = 5  # Por ejemplo, 5 teléfonos móviles por día

# Generar una variable aleatoria uniforme U ~ Uniform(0, 1)
n = 100  # Número de simulaciones
variable_uniforme = np.random.uniform(0, 1, n)

# Aplicar la transformada inversa para la distribución Poisson
def poisson_inverse_transform(lambda_poisson, U):
    k = 0
    prob_acumulada = math.exp(-lambda_poisson)  # Probabilidad acumulada inicial
    factor_exp = math.exp(-lambda_poisson)  # Guardar el valor constante
    while U > prob_acumulada:
        k += 1
        prob_acumulada += (lambda_poisson**k * factor_exp) / math.factorial(k)
    return k

# Generar demanda simulada usando transformada inversa
demanda_simulada = [poisson_inverse_transform(lambda_poisson, u) for u in variable_uniforme]

# Mostrar los resultados
print("Demanda diaria simulada:", demanda_simulada)

# Graficar histograma de la demanda simulada
plt.hist(demanda_simulada, bins=np.arange(0, max(demanda_simulada) + 1) - 0.5, edgecolor='black', density=True)
plt.title("Simulación de demanda diaria (Distribución Poisson)")
plt.xlabel("Número de productos demandados")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# Demanda diaria simulada: [4, 4, 10, 2, 3, 6, 4, 6, 10, 2, 4, 7, 6, 5, 5, 4, 6, 4, 7, 5, 8, 4, 6, 5, 6, 3, 5, 4, 8, 3, 11, 3, 2, 3, 5, 4, 4, 3, 7, 6, 1, 6, 9, 2, 5, 10, 5, 6, 3, 5, 3, 9, 4, 4, 4, 5, 8, 8, 1, 7, 3, 7, 2, 10, 10, 3, 6, 8, 9, 6, 4, 4, 4, 5, 6, 6, 2, 6, 2, 6, 4, 4, 4, 4, 3, 4, 7, 8, 4, 7, 8, 5, 5, 3, 5, 6, 3, 6, 4, 6]

# %% [markdown]
# #CONCLUSION
# ayuda a predecir la probabilidad de que ocurra un evento aleatorio en un intervalo de tiempo, es util para modelar y analizar eventos poco frecuentes o independientes
# sirve para poder tomar deciciones de manera efectiva
